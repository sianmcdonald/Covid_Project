# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import datetime as dt

# %%
covid = pd.read_csv("/Users/SianMcDonald/Documents/Data Academy/covid.csv")
gdp = pd.read_csv("//Users/SianMcDonald/Documents/Data Academy/gdp.csv")
tourism = pd.read_csv("//Users/SianMcDonald/Documents/Data Academy/tourism.csv")
pop_65 = pd.read_csv("//Users/SianMcDonald/Documents/Data Academy/pop_65.csv")
pop_desn = pd.read_csv("//Users/SianMcDonald/Documents/Data Academy/pop_dens.csv")
beds = pd.read_csv("//Users/SianMcDonald/Documents/Data Academy/beds.csv")

# %%
covid.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  4/21/2020   21      4  2020     35       2             Afghanistan    AF
# 1  4/20/2020   20      4  2020     88       3             Afghanistan    AF
# 2  4/19/2020   19      4  2020     63       0             Afghanistan    AF
# 3  4/18/2020   18      4  2020     51       1             Afghanistan    AF
# 4  4/17/2020   17      4  2020     10       4             Afghanistan    AF
#
#   countryterritoryCode  popData2018 continentExp country_code country_name
# 0                  AFG   37172386.0         Asia          AFG  Afghanistan
# 1                  AFG   37172386.0         Asia          AFG  Afghanistan
# 2                  AFG   37172386.0         Asia          AFG  Afghanistan
# 3                  AFG   37172386.0         Asia          AFG  Afghanistan
# 4                  AFG   37172386.0         Asia          AFG  Afghanistan

# %%
covid['country_code'] = covid['countryterritoryCode']
covid['country_name'] = covid['countriesAndTerritories']
covid2 = covid.drop(["countryterritoryCode","countriesAndTerritories","geoId"],axis = 1)
covid2.head()
# Out:
#      dateRep  day  month  year  cases  deaths  popData2018 continentExp  \
# 0  4/21/2020   21      4  2020     35       2   37172386.0         Asia
# 1  4/20/2020   20      4  2020     88       3   37172386.0         Asia
# 2  4/19/2020   19      4  2020     63       0   37172386.0         Asia
# 3  4/18/2020   18      4  2020     51       1   37172386.0         Asia
# 4  4/17/2020   17      4  2020     10       4   37172386.0         Asia
#
#   country_code country_name
# 0          AFG  Afghanistan
# 1          AFG  Afghanistan
# 2          AFG  Afghanistan
# 3          AFG  Afghanistan
# 4          AFG  Afghanistan

# %%
#Merging all the data together (left joins on country code and name for most as come from same source)
merged_data = covid2.merge(tourism, on='country_code', how='left')
merged_data.rename(columns={'country_name_y': 'country_name'}, inplace = True)
merged_data = merged_data.merge(gdp, on=['country_code','country_name'], how='left')
merged_data = merged_data.merge(pop_65, on=['country_code','country_name'], how = 'left')
merged_data = merged_data.merge(pop_desn, on=['country_code','country_name'], how = 'left' )
merged_data = merged_data.merge(beds, on=['country_code','country_name'], how = 'left')

# %%
merged_data.head()
# Out:
#      dateRep  day  month  year  cases  deaths  popData2018 continentExp  \
# 0  4/21/2020   21      4  2020     35       2   37172386.0         Asia
# 1  4/20/2020   20      4  2020     88       3   37172386.0         Asia
# 2  4/19/2020   19      4  2020     63       0   37172386.0         Asia
# 3  4/18/2020   18      4  2020     51       1   37172386.0         Asia
# 4  4/17/2020   17      4  2020     10       4   37172386.0         Asia
#
#   country_code country_name_x country_name  tourism         gdp    pop_65  \
# 0          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 1          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 2          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 3          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 4          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
#
#    pop_dens  beds
# 0  56.93776   0.5
# 1  56.93776   0.5
# 2  56.93776   0.5
# 3  56.93776   0.5
# 4  56.93776   0.5

# %%
def plot_cases(df, country_code):
    data = df[df['country_code'] == country_code]
    data['dateRep'] = pd.to_datetime(data['dateRep'])
    date = data['dateRep']
    cases = data['cases']
    deaths = data['deaths']
    plt.plot(date, cases, '.', color = 'green');
    plt.plot(date, deaths, '.', color = 'red')
    plt.title("Number of Covid19 Cases and Deaths in " + country_code)
    plt.xticks(rotation=90)
    plt.legend(['Cases', 'Deaths'])

# %%
plot_cases(merged_data, 'ITA')
plt.axvline(dt.datetime(2020, 3, 9))
plt.legend(['Cases', 'Deaths','Lockdown']);

# %%
plot_cases(merged_data, 'GBR')
plt.axvline(dt.datetime(2020, 3, 23))
plt.legend(['Cases', 'Deaths','Lockdown']);

# %%
plot_cases(merged_data, 'VNM')

# %%
merged_data.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths', 'popData2018',
#        'continentExp', 'country_code', 'country_name_x', 'country_name',
#        'tourism', 'gdp', 'pop_65', 'pop_dens', 'beds'],
#       dtype='object')

# %%
agg_data = pd.DataFrame(merged_data.groupby(['country_code'],sort=True)['country_code','country_name','popData2018','tourism','gdp','pop_65','pop_dens','beds'].max())
agg_data.head()
# Out:
#              country_code country_name  popData2018    tourism           gdp  \
# country_code
# ABW                   ABW        Aruba     105845.0  1082000.0  25630.266490
# AFG                   AFG  Afghanistan   37172386.0        NaN    520.896603
# AGO                   AGO       Angola   30809762.0   218000.0   3432.385736
# ALB                   ALB      Albania    2866376.0  5340000.0   5268.848504
# AND                   AND      Andorra      77006.0  3042000.0  42029.762740
#
#                 pop_65    pop_dens  beds
# country_code
# ABW            14343.0  588.027778   NaN
# AFG           960879.0   56.937760   0.5
# AGO           682859.0   24.713052   NaN
# ALB           393976.0  104.612263   2.9
# AND                NaN  163.842553   NaN

# %%
sum_cases = pd.DataFrame(merged_data.groupby(['country_code'])['cases'].sum())
sum_deaths = pd.DataFrame(merged_data.groupby(['country_code'])['deaths'].sum())

# %%
#This does the join on the index which here is country code
agg_data2 = agg_data.merge(sum_cases, left_index = True, right_index = True, how='left')
agg_data2 = agg_data2.merge(sum_deaths, left_index = True, right_index = True, how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-264-c0988466977c> in <module>
#       1 #This does the join on the index which here is country code
#       2 agg_data2 = agg_data.merge(sum_cases, left_index = True, right_index = True, how='left')
# ----> 3 agg_data2 = agg_data2.merge(sum_deaths, left_index = True, right_index = True, how='left').reset_index()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert country_code, already exists

# %%
agg_data2
# Out:
#              country_code  country_name  popData2018     tourism  \
# country_code
# ABW                   ABW         Aruba     105845.0   1082000.0
# AFG                   AFG   Afghanistan   37172386.0         NaN
# AGO                   AGO        Angola   30809762.0    218000.0
# ALB                   ALB       Albania    2866376.0   5340000.0
# AND                   AND       Andorra      77006.0   3042000.0
# ...                   ...           ...          ...         ...
# XKX                   XKX        Kosovo    1845300.0         NaN
# YEM                   YEM   Yemen, Rep.   28498687.0         NaN
# ZAF                   ZAF  South Africa   57779622.0  10472000.0
# ZMB                   ZMB        Zambia   17351822.0   1072000.0
# ZWE                   ZWE      Zimbabwe   14439018.0   2580000.0
#
#                        gdp     pop_65    pop_dens  beds  cases
# country_code
# ABW           25630.266490    14343.0  588.027778   NaN     97
# AFG             520.896603   960879.0   56.937760   0.5   1031
# AGO            3432.385736   682859.0   24.713052   NaN     24
# ALB            5268.848504   393976.0  104.612263   2.9    584
# AND           42029.762740        NaN  163.842553   NaN    717
# ...                    ...        ...         ...   ...    ...
# XKX            4302.276483        NaN  168.154680   NaN    598
# YEM             944.408499   819699.0   53.977853   0.7      1
# ZAF            6374.028196  3072723.0   47.630120   NaN   3300
# ZMB            1539.900158   364332.0   23.341479   NaN     65
# ZWE            2146.996385   424438.0   37.324591   NaN     25
#
# [202 rows x 9 columns]

# %%
#Rename the column names to be sum of cases and deaths
agg_data2.rename(columns={'cases': 'sum_cases','deaths': 'sum_deaths'},inplace = True)
#Add a column of the death rates
agg_data2['death_rate'] = agg_data2['sum_deaths']/agg_data2['sum_cases']
#Add a column for percentage of population over 65
agg_data2['perc_65_plus'] = agg_data2['pop_65']/agg_data2['popData2018']

# %%
agg_data2.shape
# Out:
# (202, 12)

# %%
agg_data2.describe()
# Out:
#         popData2018       tourism            gdp        pop_65      pop_dens  \
# count  2.010000e+02  1.780000e+02     187.000000  1.790000e+02    194.000000
# mean   3.750281e+07  7.651614e+06   18381.888688  3.717484e+06    333.482021
# std    1.417059e+08  1.456192e+07   26799.780498  1.391065e+07   1514.541442
# min    1.000000e+03  1.400000e+04     271.752044  6.174000e+03      0.136497
# 25%    1.308974e+06  4.510000e+05    2351.212688  1.441730e+05     37.370577
# 50%    7.061507e+06  1.955000e+06    7246.731656  5.823960e+05     91.177915
# 75%    2.626237e+07  8.084250e+06   23373.435025  2.081209e+06    218.004208
# max    1.392730e+09  8.932200e+07  185741.280000  1.520984e+08  19196.000000
#
#              beds      sum_cases    sum_deaths  death_rate  perc_65_plus
# count  125.000000     202.000000    202.000000  202.000000    179.000000
# mean     3.420800   12035.519802    840.851485    0.039444      0.090603
# std      2.604936   61007.746642   4176.727489    0.041722      0.063787
# min      0.300000       1.000000      0.000000    0.000000      0.010850
# 25%      1.500000      64.250000      1.000000    0.008190      0.033676
# 50%      2.800000     446.500000      9.000000    0.027456      0.070129
# 75%      4.600000    3236.500000     80.250000    0.052498      0.147170
# max     13.800000  787752.000000  42539.000000    0.200000      0.275764

# %%
agg_data2.head()
# Out:
#              country_code country_name  popData2018    tourism           gdp  \
# country_code
# ABW                   ABW        Aruba     105845.0  1082000.0  25630.266490
# AFG                   AFG  Afghanistan   37172386.0        NaN    520.896603
# AGO                   AGO       Angola   30809762.0   218000.0   3432.385736
# ALB                   ALB      Albania    2866376.0  5340000.0   5268.848504
# AND                   AND      Andorra      77006.0  3042000.0  42029.762740
#
#                 pop_65    pop_dens  beds  sum_cases  sum_deaths  death_rate  \
# country_code
# ABW            14343.0  588.027778   NaN         97           2    0.020619
# AFG           960879.0   56.937760   0.5       1031          35    0.033948
# AGO           682859.0   24.713052   NaN         24           2    0.083333
# ALB           393976.0  104.612263   2.9        584          26    0.044521
# AND                NaN  163.842553   NaN        717          36    0.050209
#
#               perc_65_plus
# country_code
# ABW               0.135509
# AFG               0.025849
# AGO               0.022164
# ALB               0.137447
# AND                    NaN

# %% [markdown]
# # What are the corralations between the variables and which are most corralated with the number of cases/deaths?

# %%
agg_data2.corr()
# Out:
#               popData2018   tourism       gdp    pop_65  pop_dens      beds  \
# popData2018      1.000000  0.370666 -0.072435  0.937351 -0.019623  0.004401
# tourism          0.370666  1.000000  0.172461  0.515919 -0.031035  0.184626
# gdp             -0.072435  0.172461  1.000000  0.046628  0.478761  0.380610
# pop_65           0.937351  0.515919  0.046628  1.000000 -0.003335  0.145832
# pop_dens        -0.019623 -0.031035  0.478761 -0.003335  1.000000  0.319339
# beds             0.004401  0.184626  0.380610  0.145832  0.319339  1.000000
# sum_cases        0.232268  0.661112  0.174719  0.378304 -0.025241  0.033523
# sum_deaths       0.185924  0.759044  0.180053  0.326905 -0.026065  0.030745
# death_rate       0.041236  0.221566 -0.003147  0.077340 -0.038826 -0.091326
# perc_65_plus    -0.008909  0.413695  0.571697  0.130430  0.041226  0.671054
#
#               sum_cases  sum_deaths  death_rate  perc_65_plus
# popData2018    0.232268    0.185924    0.041236     -0.008909
# tourism        0.661112    0.759044    0.221566      0.413695
# gdp            0.174719    0.180053   -0.003147      0.571697
# pop_65         0.378304    0.326905    0.077340      0.130430
# pop_dens      -0.025241   -0.026065   -0.038826      0.041226
# beds           0.033523    0.030745   -0.091326      0.671054
# sum_cases      1.000000    0.913302    0.144557      0.228028
# sum_deaths     0.913302    1.000000    0.280504      0.284657
# death_rate     0.144557    0.280504    1.000000      0.130828
# perc_65_plus   0.228028    0.284657    0.130828      1.000000

# %%
Var_Corr = agg_data2.corr()
# plot the heatmap and annotation on it
plt.figure(figsize=(12,8), dpi=80, facecolor='w', edgecolor='k')
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True);

# %% [markdown]
# ## We see that tourism is the most positively corralated with the number of cases which makes sense, as the more people visiting a country, the easy the virus will spread.

# %% [markdown]
# # Questions
#
# 2. Plot tourism against cases
# 3. Decide on which questions we are asking and answering
# 4. What is the death rate of countries
# 5. how to draw line from day 1 with 100 deatsh
# 4. try and make a graph of all countries on 1 graph
# 5. Can we fit a model to Italy
# 6. Can we use this to predict cases in the UK?

# %%
agg_data2[agg_data2['sum_cases'] > 700000]
# Out:
#              country_code   country_name  popData2018     tourism  \
# country_code
# USA                   USA  United States  327167434.0  79745920.0
#
#                       gdp      pop_65   pop_dens  beds  sum_cases  sum_deaths  \
# country_code
# USA           62794.58565  51641630.0  35.766089   2.9     787752       42539
#
#               death_rate  perc_65_plus
# country_code
# USA                0.054      0.157845

# %%
#There are only 24 null values so we will fill them with 0
x = agg_data2['tourism'].fillna(0)
y = agg_data2['sum_cases']
#We are logging the data as without it the data is skewed as some countries cases have grown exponentially (e.g. USA with 780k cases)
plt.plot(np.log(x +1),np.log(y+1),'.')
plt.xlabel("Log tourism values")
plt.ylabel("Log sum of total cases");
#plt.boxplot(y)

# %%
#If we drop the values with null tourism we should have a better plot
agg_data3 = agg_data2.dropna(subset=['tourism'])
x = agg_data3['tourism']
y = agg_data3['sum_cases']
plt.plot(np.log(x +1),np.log(y+1),'.')
plt.xlabel("Log tourism values")
plt.ylabel("Log sum of total cases");
#plt.boxplot(y)

# %% [markdown]
# Removing null values, and logging both variables we see a strong positive corralation between tourism numbers and the total cases a coutnry has. This tourism number is ....
# This is expected as the most visitors a country has the most likely they will be to aide the spread of the virus

# %% [markdown]
# # Which top 5 countries have the most infections?

# %%
top5_cases = agg_data2.sort_values('sum_cases',ascending=False).head()
top5_cases
# Out:
#              country_code    country_name  popData2018     tourism  \
# country_code
# USA                   USA   United States  327167434.0  79745920.0
# ESP                   ESP           Spain   46723749.0  82773000.0
# ITA                   ITA           Italy   60431283.0  61567200.0
# DEU                   DEU         Germany   82927922.0  38881000.0
# GBR                   GBR  United Kingdom   66488991.0  36316000.0
#
#                       gdp      pop_65    pop_dens  beds  sum_cases  \
# country_code
# USA           62794.58565  51641630.0   35.766089   2.9     787752
# ESP           30370.89233   9068471.0   93.529058   3.0     200210
# ITA           34483.20400  13746965.0  205.450748   3.4     181228
# DEU           47603.02763  17793207.0  237.370970   8.3     143457
# GBR           42943.90227  12225956.0  274.827392   2.8     124743
#
#               sum_deaths  death_rate  perc_65_plus
# country_code
# USA                42539    0.054000      0.157845
# ESP                20852    0.104151      0.194087
# ITA                24114    0.133059      0.227481
# DEU                 4598    0.032051      0.214562
# GBR                16509    0.132344      0.183879

# %%
sns.barplot(top5_cases['country_name'], top5_cases['sum_cases'])
plt.title('Total Cases for the top 5 countries')
plt.xlabel('Total Cases')
plt.ylabel('Country')

# Add labels to the plot
plt.text(-0.3,791000,'787,752')
plt.text(0.7,206000,'200,210')
plt.text(1.7,190000,'181,228')
plt.text(2.7,150000,'143,457')
plt.text(3.7,130000,'124,743');

# %% [markdown]
# The USA, Spain, Italy, Germany and the UK currently have the highest number of total cases.

# %% [markdown]
# # Which countries have the top 5 deaths?

# %%
top5_deaths = agg_data2.sort_values('sum_deaths',ascending=False).head()
top5_deaths
# Out:
#              country_code    country_name  popData2018     tourism  \
# country_code
# USA                   USA   United States  327167434.0  79745920.0
# ITA                   ITA           Italy   60431283.0  61567200.0
# ESP                   ESP           Spain   46723749.0  82773000.0
# FRA                   FRA          France   66987244.0  89322000.0
# GBR                   GBR  United Kingdom   66488991.0  36316000.0
#
#                       gdp      pop_65    pop_dens  beds  sum_cases  \
# country_code
# USA           62794.58565  51641630.0   35.766089   2.9     787752
# ITA           34483.20400  13746965.0  205.450748   3.4     181228
# ESP           30370.89233   9068471.0   93.529058   3.0     200210
# FRA           41463.64402  13418612.0  122.338396   6.5     114657
# GBR           42943.90227  12225956.0  274.827392   2.8     124743
#
#               sum_deaths  death_rate  perc_65_plus
# country_code
# USA                42539    0.054000      0.157845
# ITA                24114    0.133059      0.227481
# ESP                20852    0.104151      0.194087
# FRA                20265    0.176745      0.200316
# GBR                16509    0.132344      0.183879

# %%
sns.barplot(top5_deaths['country_name'], top5_deaths['sum_deaths'])
plt.title('Total Deaths for the top 5 countries')
plt.xlabel('Total Deaths')
plt.ylabel('Country')

# Add labels to the plot
plt.text(-0.3,42700,'42,539')
plt.text(0.7,24500,'24,114')
plt.text(1.7,21200,'20,852')
plt.text(2.7,20700,'20,265')
plt.text(3.7,17000,'16,509');

# %% [markdown]
# France is now in the top 5 but USA, Italy and Spain keep the lead with the highest number of deaths

# %% [markdown]
# # Which 5 countries have the highest death rate

# %%
top5_death_rates = agg_data2.sort_values('death_rate',ascending=False).head()
top5_death_rates
# Out:
#              country_code               country_name  popData2018     tourism  \
# country_code
# VGB                   VGB     British Virgin Islands      29802.0    192000.0
# FRA                   FRA                     France   66987244.0  89322000.0
# BDI                   BDI                    Burundi   11175378.0    299000.0
# NIC                   NIC                  Nicaragua    6465513.0   1256000.0
# SXM                   SXM  Sint Maarten (Dutch part)      41486.0    178000.0
#
#                        gdp      pop_65     pop_dens  beds  sum_cases  \
# country_code
# VGB                    NaN         NaN   198.680000   NaN          5
# FRA           41463.644020  13418612.0   122.338396   6.5     114657
# BDI             271.752044    251104.0   435.178271   0.8          6
# NIC            2028.894755    339278.0    53.727048   0.9         13
# SXM                    NaN         NaN  1193.352941   NaN         68
#
#               sum_deaths  death_rate  perc_65_plus
# country_code
# VGB                    1    0.200000           NaN
# FRA                20265    0.176745      0.200316
# BDI                    1    0.166667      0.022469
# NIC                    2    0.153846      0.052475
# SXM                   10    0.147059           NaN

# %%
sns.barplot(top5_death_rates['country_name'], top5_death_rates['death_rate'])
plt.title('Death Rates for the top 5 countries')
plt.xlabel('Death rate')
plt.ylabel('Country');

# %% [markdown]
# The country with the highest death rate at the moment is the British Virgin Islands, this because they have 5 cases and 1 death. If we look at countries with over 10,000 deaths what do we get instead?

# %%
data3 = agg_data2[agg_data2['sum_deaths']>10000]
top5_death_rates_v2 = data3.sort_values('death_rate',ascending=False).head()
top5_death_rates_v2
# Out:
#              country_code    country_name  popData2018     tourism  \
# country_code
# FRA                   FRA          France   66987244.0  89322000.0
# ITA                   ITA           Italy   60431283.0  61567200.0
# GBR                   GBR  United Kingdom   66488991.0  36316000.0
# ESP                   ESP           Spain   46723749.0  82773000.0
# USA                   USA   United States  327167434.0  79745920.0
#
#                       gdp      pop_65    pop_dens  beds  sum_cases  \
# country_code
# FRA           41463.64402  13418612.0  122.338396   6.5     114657
# ITA           34483.20400  13746965.0  205.450748   3.4     181228
# GBR           42943.90227  12225956.0  274.827392   2.8     124743
# ESP           30370.89233   9068471.0   93.529058   3.0     200210
# USA           62794.58565  51641630.0   35.766089   2.9     787752
#
#               sum_deaths  death_rate  perc_65_plus
# country_code
# FRA                20265    0.176745      0.200316
# ITA                24114    0.133059      0.227481
# GBR                16509    0.132344      0.183879
# ESP                20852    0.104151      0.194087
# USA                42539    0.054000      0.157845

# %%
sns.barplot(top5_death_rates_v2['country_name'], top5_death_rates_v2['death_rate'])
plt.title('Death Rates for the top 5 countries with over 10,000 deaths')
plt.xlabel('Death rate')
plt.ylabel('Country');

# %% [markdown]
# **Ask Saad how to make the colours of this dependent on another variable
#
# We see that France has the highest death rate followed by Italy, with the US coming in last.
# Interestingly, France, out of these 5 has the highest number of beds per 1000 people (6.5) and USA has the least (2.9) suggesting a negative corralation between these variables which doesn't really make sense. It could be that more bed imply a more advance medical system and hence they are doing more testing.
#
# The testing data is not very clear from what I have found, with different countries using different measures leading to inconsistent results so I will not bring it in to my data set. From the data found here:https://github.com/owid/covid-19-data/blob/master/public/data/testing/covid-testing.xlsx
# Italy and Spain have the highest levels of cumulative tests performed per 1000 people (24 and 20 respectively) and the UK is much further behind with 8. France and the US have unclear units so we can not really compare them.
#
# France and Italy have similar percentages of 65+ people in their population so this could elevate their death rate, and the UK's lack of testing will elevate it's death rate comparitively.

# %% [markdown]
# # How are we doing against the virus? Are we flattening the curve?
# ## Make the cool cumulative graph

# %%
merged_data.head()
merged_data['dateRep'] = pd.to_datetime(merged_data['dateRep'])
# Out:
#      dateRep  day  month  year  cases  deaths  popData2018 continentExp  \
# 0 2020-04-21   21      4  2020     35       2   37172386.0         Asia
# 1 2020-04-20   20      4  2020     88       3   37172386.0         Asia
# 2 2020-04-19   19      4  2020     63       0   37172386.0         Asia
# 3 2020-04-18   18      4  2020     51       1   37172386.0         Asia
# 4 2020-04-17   17      4  2020     10       4   37172386.0         Asia
#
#   country_code country_name_x country_name  tourism         gdp    pop_65  \
# 0          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 1          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 2          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 3          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
# 4          AFG    Afghanistan  Afghanistan      NaN  520.896603  960879.0
#
#    pop_dens  beds
# 0  56.93776   0.5
# 1  56.93776   0.5
# 2  56.93776   0.5
# 3  56.93776   0.5
# 4  56.93776   0.5

# %%
subset = merged_data[['dateRep','cases','deaths', 'country_code']]

# %%
cum_data = subset.groupby(['country_code', 'dateRep']).sum().groupby(level=0).cumsum().reset_index()
cum_data.rename(columns = {'cases': 'cum_cases','deaths': 'cum_deaths'}, inplace = True)
cum_data.head()
# Out:
#   country_code    dateRep  cum_cases  cum_deaths
# 0          ABW 2020-03-13          2           0
# 1          ABW 2020-03-20          4           0
# 2          ABW 2020-03-24         12           0
# 3          ABW 2020-03-25         17           0
# 4          ABW 2020-03-26         19           0

# %%
cum_data[cum_data['country_code'] =='GBR']
# Out:
#      country_code    dateRep  cum_cases  cum_deaths
# 4094          GBR 2019-12-31          0           0
# 4095          GBR 2020-01-01          0           0
# 4096          GBR 2020-01-02          0           0
# 4097          GBR 2020-01-03          0           0
# 4098          GBR 2020-01-04          0           0
# ...           ...        ...        ...         ...
# 4202          GBR 2020-04-17     103093       13729
# 4203          GBR 2020-04-18     108692       14576
# 4204          GBR 2020-04-19     114217       15464
# 4205          GBR 2020-04-20     120067       16060
# 4206          GBR 2020-04-21     124743       16509
#
# [113 rows x 4 columns]

# %%
# Get data where number of deaths > 100
gt_100_dt = cum_data[cum_data['cum_deaths']>100]
# Out:
#       country_code    dateRep  cum_cases  cum_deaths
# 393            ARG 2020-04-15       2432         105
# 394            ARG 2020-04-16       2432         109
# 395            ARG 2020-04-17       2560         115
# 396            ARG 2020-04-18       2658         122
# 397            ARG 2020-04-19       2828         132
# ...            ...        ...        ...         ...
# 11588          USA 2020-04-17     671331       33284
# 11589          USA 2020-04-18     702164       37054
# 11590          USA 2020-04-19     735086       38910
# 11591          USA 2020-04-20     759687       40682
# 11592          USA 2020-04-21     787752       42539
#
# [957 rows x 4 columns]

# %%
dataset = gt_100_dt[gt_100_dt['country_code'] =='ARG']
a = dataset.iloc[0]['dateRep']

dataset['new_col'] = dataset['dateRep'] - a
# Out:
# 2 days 00:00:00
#     country_code    dateRep  cum_cases  cum_deaths new_col
# 393          ARG 2020-04-15       2432         105  0 days
# 394          ARG 2020-04-16       2432         109  1 days
# 395          ARG 2020-04-17       2560         115  2 days
# 396          ARG 2020-04-18       2658         122  3 days
# 397          ARG 2020-04-19       2828         132  4 days
# 398          ARG 2020-04-20       2930         134  5 days
# 399          ARG 2020-04-21       3020         142  6 days

# %%
dataset2 = gt_100_dt[gt_100_dt['country_code'] =='USA']
a = dataset2.iloc[0]['dateRep']

dataset2['new_col'] = dataset2['dateRep'] - a
dataset2
# Out:
#       country_code    dateRep  cum_cases  cum_deaths new_col
# 11558          USA 2020-03-18       6427         108  0 days
# 11559          USA 2020-03-19       9415         150  1 days
# 11560          USA 2020-03-20      14250         150  2 days
# 11561          USA 2020-03-21      19624         260  3 days
# 11562          USA 2020-03-22      26747         340  4 days
# 11563          USA 2020-03-23      35206         471  5 days
# 11564          USA 2020-03-24      46442         590  6 days
# 11565          USA 2020-03-25      55231         801  7 days
# 11566          USA 2020-03-26      69194        1050  8 days
# 11567          USA 2020-03-27      85991        1296  9 days
# 11568          USA 2020-03-28     104686        1707 10 days
# 11569          USA 2020-03-29     124665        2191 11 days
# 11570          USA 2020-03-30     143025        2509 12 days
# 11571          USA 2020-03-31     164620        3170 13 days
# 11572          USA 2020-04-01     189618        4079 14 days
# 11573          USA 2020-04-02     216721        5138 15 days
# 11574          USA 2020-04-03     245540        6053 16 days
# 11575          USA 2020-04-04     277965        7157 17 days
# 11576          USA 2020-04-05     312237        8501 18 days
# 11577          USA 2020-04-06     337635        9647 19 days
# 11578          USA 2020-04-07     368196       10989 20 days
# 11579          USA 2020-04-08     398809       12895 21 days
# 11580          USA 2020-04-09     432132       14817 22 days
# 11581          USA 2020-04-10     466033       16690 23 days
# 11582          USA 2020-04-11     501560       18777 24 days
# 11583          USA 2020-04-12     529951       20608 25 days
# 11584          USA 2020-04-13     557571       22108 26 days
# 11585          USA 2020-04-14     582594       23649 27 days
# 11586          USA 2020-04-15     609516       26057 28 days
# 11587          USA 2020-04-16     639664       30985 29 days
# 11588          USA 2020-04-17     671331       33284 30 days
# 11589          USA 2020-04-18     702164       37054 31 days
# 11590          USA 2020-04-19     735086       38910 32 days
# 11591          USA 2020-04-20     759687       40682 33 days
# 11592          USA 2020-04-21     787752       42539 34 days

# %%
# Creating an empty Dataframe with column names only
final_data = pd.DataFrame(columns=['country_code', 'dateRep', 'cum_cases','cum_deaths','days_since_100'])
final_data
# Out:
# Empty DataFrame
# Columns: [country_code, dateRep, cum_cases, cum_deaths, days_since_100]
# Index: []

# %%
pd.DataFrame(merged_data.groupby(['country_code'])['cases'].sum())

# %%
#Create an empty data set to append to
final_data = pd.DataFrame(columns=['country_code', 'dateRep', 'cum_cases','cum_deaths','days_since_100'])

for i in pd.DataFrame(gt_100_dt.groupby(['country_code'])['country_code'])[0]:
    dataset = gt_100_dt[gt_100_dt['country_code'] == i]
    start_date = dataset.iloc[0]['dateRep']
    dataset['days_since_100'] = dataset['dateRep'] - start_date
    final_data = final_data.append(dataset)

# %%
final_data
# Out:
#       country_code    dateRep cum_cases cum_deaths days_since_100
# 393            ARG 2020-04-15      2432        105         0 days
# 394            ARG 2020-04-16      2432        109         1 days
# 395            ARG 2020-04-17      2560        115         2 days
# 396            ARG 2020-04-18      2658        122         3 days
# 397            ARG 2020-04-19      2828        132         4 days
# ...            ...        ...       ...        ...            ...
# 11588          USA 2020-04-17    671331      33284        30 days
# 11589          USA 2020-04-18    702164      37054        31 days
# 11590          USA 2020-04-19    735086      38910        32 days
# 11591          USA 2020-04-20    759687      40682        33 days
# 11592          USA 2020-04-21    787752      42539        34 days
#
# [957 rows x 5 columns]

# %%
final_data.dtypes
# Out:
# country_code               object
# dateRep            datetime64[ns]
# cum_cases                  object
# cum_deaths                 object
# days_since_100    timedelta64[ns]
# dtype: object

# %%
final_data['cum_cases'] = final_data['cum_cases'].astype(float)
final_data['cum_deaths'] = final_data['cum_deaths'].astype(float)

# %%
final_data['country_code'].unique()
# Out:
# array(['ARG', 'AUT', 'BEL', 'BGD', 'BRA', 'CAN', 'CHE', 'CHL', 'CHN',
#        'COL', 'CZE', 'DEU', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ESP',
#        'FRA', 'GBR', 'GRC', 'HUN', 'IDN', 'IND', 'IRL', 'IRN', 'ISR',
#        'ITA', 'JPN', 'KOR', 'MAR', 'MEX', 'NLD', 'NOR', 'PAK', 'PAN',
#        'PER', 'PHL', 'POL', 'PRT', 'ROU', 'RUS', 'SAU', 'SRB', 'SWE',
#        'TUR', 'UKR', 'USA'], dtype=object)

# %%
x = final_data[final_data['country_code'] == 'USA']['days_since_100']
y = final_data[final_data['country_code'] == 'USA']['cum_deaths']

plt.plot(x,np.log(y+1))
plt.plot(final_data[final_data['country_code'] == 'GBR']['days_since_100'], np.log(final_data[final_data['country_code'] == 'GBR']['cum_deaths'] +1))
plt.plot(final_data[final_data['country_code'] == 'ITA']['days_since_100'], np.log(final_data[final_data['country_code'] == 'ITA']['cum_deaths'] +1))
plt.plot(final_data[final_data['country_code'] == 'ARG']['days_since_100'], np.log(final_data[final_data['country_code'] == 'ARG']['cum_deaths'] +1))
plt.plot(final_data[final_data['country_code'] == 'ESP']['days_since_100'], np.log(final_data[final_data['country_code'] == 'ESP']['cum_deaths'] +1))

# %%
for i in pd.DataFrame(gt_100_dt.groupby(['country_code'])['country_code'])[0]:
    x = final_data[final_data['country_code'] == i]['days_since_100']
    y = final_data[final_data['country_code'] == i]['cum_deaths']
    plt.plot(x,np.log(y+1))
